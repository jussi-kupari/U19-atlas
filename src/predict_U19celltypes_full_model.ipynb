# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import os
from pathlib import Path
from collections import Counter

import anndata
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

import pollock.utils as utils
import pollock.explain as explain

# %%
model = utils.load_model('models/mouse_atlas_humanized_sharma')
# Out:
# /datb/pe/jussi/pollock/env/lib/python3.11/site-packages/pollock/utils.py:207: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_fp, map_location=torch.device('cpu')))

# %%
query = anndata.read_h5ad('data/U19_atlas.h5ad')

# %%
# note that if you are predicting a large dataset and don't need the pollock umap embeddings you can set make_umap to False to increase runtime speed
adata = utils.predict_adata(model, query, make_umap=True)
adata
# Out:
# 2025-09-08 15:56:04,295 13882 genes overlap with model after filtering
# 2025-09-08 15:56:04,296 750 genes missing from dataset after filtering
# /datb/pe/jussi/pollock/env/lib/python3.11/site-packages/anndata/_core/merge.py:1434: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(
# /datb/pe/jussi/pollock/env/lib/python3.11/site-packages/pollock/dataloaders.py:104: FutureWarning: Use sc.pp.normalize_total instead
#   sc.pp.normalize_per_cell(adata)
# /datb/pe/jussi/pollock/env/lib/python3.11/site-packages/scanpy/preprocessing/_simple.py:589: FutureWarning: Use sc.pp.normalize_total instead
#   normalize_per_cell(
# 2025-09-08 15:56:56,166 starting prediction of 53596 cells
# /datb/pe/jussi/pollock/env/lib/python3.11/site-packages/pollock/dataloaders.py:144: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sf = self.adata.obs['size_factors'][idx]
# AnnData object with n_obs × n_vars = 53596 × 14632
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Study', 'Species', 'Cell_or_nuclei', 'Platform', 'percent.mt', 'integrated_snn_res.1', 'seurat_clusters', 'tSNE_1', 'tSNE_2', 'UMAP_1', 'UMAP_2', 'Level1', 'Donor', 'Batch', 'tech', 'integrated_snn_res.0.5', 'tissue', 'level1', 'integrated_snn_res.0.1', 'integrated_snn_res.3.4', 'cl.conserv', 'cl.HC.LC.split', 'cl.Ab.split.3', 'cl.Ab.split.4', 'diameter', 'drg_level', 'drg_location', 'batch', 'donor', 'cl.conserv_final', 'Strain', 'Sex', 'Age', 'Publication', 'Prep', 'Condition', 'Library', 'Level', 'sex', 'round', 'id', 'nn_score1', 'nn_score2', 'nn_score3', 'nn_score4', 'nn_score5', 'nn_score6', 'nn_score7', 'nn_score8', 'nn_score9', 'nn_score10', 'nn_score11', 'nn_score12', 'nn_score13', 'nn_score14', 'nn_score15', 'nn_score16', 'nn_score17', 'nn_score18', 'nn_score19', 'nn_score20', 'nn_score21', 'nn_score22', 'nn_score23', 'nn_score24', 'nn_score25', 'nn_score26', 'Level2_round1', 'Level2_round2', 'Row.names', 'Level3', 'Final', 'barcode_raw', 'orig.ident.x', 'nCount_RNA.x', 'nFeature_RNA.x', 'seurat_clusters.x', 'integrated_snn_res.3.4.x', 'barcode_key.x', 'barcode_key.y', 'barcode_raw_lcm', 'orig.ident.y', 'nCount_RNA.y', 'nFeature_RNA.y', 'integrated_snn_res.3.4.y', 'seurat_clusters.y', 'PS005.over.004.fix', 'res.4.processed', 'Atlas_annotation', 'MT.ratio', 'NUCL.ratio', 'snn_res.3.and.16.17', 'res.3.16.17.to.names', 'res.3.names.ord', 'res.3.clean.final', 'integrated_snn_res.4', 'integrated_snn_res.4.5', 'fuse.PS005.over.004.w.948', 'res.4.named.1391.1', 'res.4.named.1391.2', 'integrated_snn_res.5', 'res.4.named.1391.2.ord', 'res.4.named.1391.2.EXPLOR', 'Final.ord', 'Myel.module1', 'Myel.mod.scaled1', 'Myel.mod.counts1', 'Berlin.1', 'Berlin.2', 'Berlin.3', 'n_counts', 'size_factors', 'y_pred', 'predicted_cell_type_probability', 'predicted_cell_type', 'probability ATF3+', 'probability Ab-RA-LTMR', 'probability Ab-SA/Field', 'probability Ad-LTMR', 'probability C-LTMR', 'probability Mrgprb4', 'probability NP1', 'probability NP2', 'probability NP3', 'probability PEP1.1.a', 'probability PEP1.1.b', 'probability PEP1.2', 'probability PEP1.3.a', 'probability PEP1.3.b', 'probability PEP1.4', 'probability PEP2.1', 'probability PEP2.2', 'probability PEP3.1', 'probability PEP3.2', 'probability Proprioceptor', 'probability Rxfp1', 'probability TRPM8.1', 'probability TRPM8.2'
#     var: 'mean', 'std'
#     uns: 'log1p'
#     obsm: 'X_emb', 'X_umap', 'prediction_probs'

# %%
adata.obs
# Out:
#                                  orig.ident  nCount_RNA  nFeature_RNA  \
# TATATCCTCATCCACC-1_1_1        SeuratProject    271917.0         12362
# CAAGAACCATAATCGT-1_1_1        SeuratProject    154655.0         11439
# AATCAGGAGAATCGCT-1_1_1        SeuratProject     84579.0          8892
# TTATTGCTCCGGAACC-1_1_1        SeuratProject     82656.0          9544
# TTATAGCCAATTGAGA-1_1_1        SeuratProject     78058.0          8946
# ...                                     ...         ...           ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8           m4r2     11540.0          4309
# s8r2m.TTCTGCTAGACTCCAA.1_7_8           m4r2      9430.0          3647
# s8r2m.TTGAGCAGCCCACGGT.1_7_8           m4r2      9338.0          3691
# s8r2m.TTGCTGATCATGTTCG.1_7_8           m4r2     11859.0          4116
# s8r2m.TTGGGACGTAAGAGTT.1_7_8           m4r2     11170.0          4214
#
#                                               Study Species Cell_or_nuclei  \
# TATATCCTCATCCACC-1_1_1                      U19_HMS   Human         Nuclei
# CAAGAACCATAATCGT-1_1_1                      U19_HMS   Human         Nuclei
# AATCAGGAGAATCGCT-1_1_1                      U19_HMS   Human         Nuclei
# TTATTGCTCCGGAACC-1_1_1                      U19_HMS   Human         Nuclei
# TTATAGCCAATTGAGA-1_1_1                      U19_HMS   Human         Nuclei
# ...                                             ...     ...            ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8  Tavares-Ferriera_2022   Human           Cell
# s8r2m.TTCTGCTAGACTCCAA.1_7_8  Tavares-Ferriera_2022   Human           Cell
# s8r2m.TTGAGCAGCCCACGGT.1_7_8  Tavares-Ferriera_2022   Human           Cell
# s8r2m.TTGCTGATCATGTTCG.1_7_8  Tavares-Ferriera_2022   Human           Cell
# s8r2m.TTGGGACGTAAGAGTT.1_7_8  Tavares-Ferriera_2022   Human           Cell
#
#                              Platform  percent.mt  integrated_snn_res.1  \
# TATATCCTCATCCACC-1_1_1            10x    0.015446                     9
# CAAGAACCATAATCGT-1_1_1            10x    0.086644                    15
# AATCAGGAGAATCGCT-1_1_1            10x    0.001182                     3
# TTATTGCTCCGGAACC-1_1_1            10x    0.008469                    14
# TTATAGCCAATTGAGA-1_1_1            10x    0.111456                    21
# ...                               ...         ...                   ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8   Visium    3.899480                     0
# s8r2m.TTCTGCTAGACTCCAA.1_7_8   Visium    3.467656                     7
# s8r2m.TTGAGCAGCCCACGGT.1_7_8   Visium    1.713429                     4
# s8r2m.TTGCTGATCATGTTCG.1_7_8   Visium    2.765832                     6
# s8r2m.TTGGGACGTAAGAGTT.1_7_8   Visium    4.037601                     3
#
#                               seurat_clusters  ...  probability PEP1.3.b  \
# TATATCCTCATCCACC-1_1_1                     11  ...              0.055154
# CAAGAACCATAATCGT-1_1_1                     12  ...              0.041955
# AATCAGGAGAATCGCT-1_1_1                     52  ...              0.047191
# TTATTGCTCCGGAACC-1_1_1                     31  ...              0.060390
# TTATAGCCAATTGAGA-1_1_1                     73  ...              0.080214
# ...                                       ...  ...                   ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8               10  ...              0.022575
# s8r2m.TTCTGCTAGACTCCAA.1_7_8               13  ...              0.104490
# s8r2m.TTGAGCAGCCCACGGT.1_7_8                4  ...              0.031512
# s8r2m.TTGCTGATCATGTTCG.1_7_8               16  ...              0.068232
# s8r2m.TTGGGACGTAAGAGTT.1_7_8               28  ...              0.016395
#
#                               probability PEP1.4  probability PEP2.1  \
# TATATCCTCATCCACC-1_1_1                  0.036455            0.018388
# CAAGAACCATAATCGT-1_1_1                  0.033837            0.022907
# AATCAGGAGAATCGCT-1_1_1                  0.053107            0.024810
# TTATTGCTCCGGAACC-1_1_1                  0.040188            0.015362
# TTATAGCCAATTGAGA-1_1_1                  0.045086            0.013247
# ...                                          ...                 ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8            0.011615            0.086992
# s8r2m.TTCTGCTAGACTCCAA.1_7_8            0.071552            0.029654
# s8r2m.TTGAGCAGCCCACGGT.1_7_8            0.041420            0.016759
# s8r2m.TTGCTGATCATGTTCG.1_7_8            0.028896            0.027883
# s8r2m.TTGGGACGTAAGAGTT.1_7_8            0.026802            0.133700
#
#                               probability PEP2.2 probability PEP3.1  \
# TATATCCTCATCCACC-1_1_1                  0.041872           0.041782
# CAAGAACCATAATCGT-1_1_1                  0.058007           0.035952
# AATCAGGAGAATCGCT-1_1_1                  0.036411           0.013827
# TTATTGCTCCGGAACC-1_1_1                  0.045447           0.032136
# TTATAGCCAATTGAGA-1_1_1                  0.054279           0.032135
# ...                                          ...                ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8            0.031041           0.070326
# s8r2m.TTCTGCTAGACTCCAA.1_7_8            0.006274           0.027147
# s8r2m.TTGAGCAGCCCACGGT.1_7_8            0.034662           0.133677
# s8r2m.TTGCTGATCATGTTCG.1_7_8            0.083718           0.073919
# s8r2m.TTGGGACGTAAGAGTT.1_7_8            0.042002           0.010344
#
#                              probability PEP3.2 probability Proprioceptor  \
# TATATCCTCATCCACC-1_1_1                 0.040649                  0.034664
# CAAGAACCATAATCGT-1_1_1                 0.036766                  0.024779
# AATCAGGAGAATCGCT-1_1_1                 0.030376                  0.205478
# TTATTGCTCCGGAACC-1_1_1                 0.028300                  0.028608
# TTATAGCCAATTGAGA-1_1_1                 0.033310                  0.029986
# ...                                         ...                       ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8           0.020169                  0.012482
# s8r2m.TTCTGCTAGACTCCAA.1_7_8           0.031081                  0.045845
# s8r2m.TTGAGCAGCCCACGGT.1_7_8           0.047249                  0.009569
# s8r2m.TTGCTGATCATGTTCG.1_7_8           0.022316                  0.021593
# s8r2m.TTGGGACGTAAGAGTT.1_7_8           0.010733                  0.081599
#
#                              probability Rxfp1 probability TRPM8.1  \
# TATATCCTCATCCACC-1_1_1                0.043205            0.051417
# CAAGAACCATAATCGT-1_1_1                0.068844            0.032704
# AATCAGGAGAATCGCT-1_1_1                0.033315            0.085612
# TTATTGCTCCGGAACC-1_1_1                0.079577            0.064570
# TTATAGCCAATTGAGA-1_1_1                0.050981            0.034096
# ...                                        ...                 ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8          0.031562            0.056649
# s8r2m.TTCTGCTAGACTCCAA.1_7_8          0.038553            0.208063
# s8r2m.TTGAGCAGCCCACGGT.1_7_8          0.060645            0.036045
# s8r2m.TTGCTGATCATGTTCG.1_7_8          0.044299            0.078206
# s8r2m.TTGGGACGTAAGAGTT.1_7_8          0.059462            0.037889
#
#                              probability TRPM8.2
# TATATCCTCATCCACC-1_1_1                  0.035218
# CAAGAACCATAATCGT-1_1_1                  0.038080
# AATCAGGAGAATCGCT-1_1_1                  0.024505
# TTATTGCTCCGGAACC-1_1_1                  0.044042
# TTATAGCCAATTGAGA-1_1_1                  0.039627
# ...                                          ...
# s8r2m.TTCTAACCGAAGCTTA.1_7_8            0.042578
# s8r2m.TTCTGCTAGACTCCAA.1_7_8            0.026464
# s8r2m.TTGAGCAGCCCACGGT.1_7_8            0.123704
# s8r2m.TTGCTGATCATGTTCG.1_7_8            0.065156
# s8r2m.TTGGGACGTAAGAGTT.1_7_8            0.036136
#
# [53596 rows x 141 columns]

# %%
# Save predictions as a .csv
adata.obs.to_csv('U19_predictions_full_model.csv')
